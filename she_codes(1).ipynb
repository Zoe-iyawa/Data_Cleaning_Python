# %%
# purpose of this dataset is to predict whether the customer can get a credit/loan. The first step is to clean the data.
# Out:
# Hello world !!

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/zoephilipiyawa/PycharmProjects/pythonProject2/credit_customers.csv')

# %%
df
# Out:
#      checking_status  duration                  credit_history  \
# 0                 <0         6  critical/other existing credit
# 1           0<=X<200        48                   existing paid
# 2        no checking        12  critical/other existing credit
# 3                 <0        42                   existing paid
# 4                 <0        24              delayed previously
# ...              ...       ...                             ...
# 1002              <0        24  critical/other existing credit
# 1003              <0        15                   existing paid
# 1004              <0        24                   existing paid
# 1005     no checking        24  critical/other existing credit
# 1006              <0        30             no credits/all paid
#
#                   purpose  credit_amount    savings_status employment  \
# 0                radio/tv         1169.0  no known savings        >=7
# ...

# %%
df.isnull().sum() #check for null values
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   1
# credit_amount             1
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       1
# other_payment_plans       1
# housing                   0
# existing_credits          0
# job                       1
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
df.info() #check data type of columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1007 non-null   object
#  1   duration                1007 non-null   int64
#  2   credit_history          1007 non-null   object
#  3   purpose                 1006 non-null   object
#  4   credit_amount           1006 non-null   float64
#  5   savings_status          1007 non-null   object
#  6   employment              1007 non-null   object
#  7   installment_commitment  1007 non-null   int64
#  8   personal_status         1007 non-null   object
#  9   other_parties           1007 non-null   object
#  10  residence_since         1007 non-null   int64
#  11  property_magnitude      1007 non-null   object
#  12  age                     1006 non-null   float64
#  13  other_payment_plans     1006 non-null   object
# ...

# %%
df = df.fillna('No response') #fill empty cells
df
# Out:
#      checking_status  duration                  credit_history  \
# 0                 <0         6  critical/other existing credit
# 1           0<=X<200        48                   existing paid
# 2        no checking        12  critical/other existing credit
# 3                 <0        42                   existing paid
# 4                 <0        24              delayed previously
# ...              ...       ...                             ...
# 1002              <0        24  critical/other existing credit
# 1003              <0        15                   existing paid
# 1004              <0        24                   existing paid
# 1005     no checking        24  critical/other existing credit
# 1006              <0        30             no credits/all paid
#
#                   purpose credit_amount    savings_status employment  \
# 0                radio/tv        1169.0  no known savings        >=7
# ...

# %%
df.isnull().sum()
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
df = df.drop_duplicates() # drop duplicates
df
# Out:
#      checking_status  duration                  credit_history  \
# 0                 <0         6  critical/other existing credit
# 1           0<=X<200        48                   existing paid
# 2        no checking        12  critical/other existing credit
# 3                 <0        42                   existing paid
# 4                 <0        24              delayed previously
# ...              ...       ...                             ...
# 997      no checking        12                   existing paid
# 998               <0        45                   existing paid
# 999         0<=X<200        45  critical/other existing credit
# 1000              <0        48                   existing paid
# 1005     no checking        24  critical/other existing credit
#
#                   purpose credit_amount    savings_status  employment  \
# 0                radio/tv        1169.0  no known savings         >=7
# ...

# %%
df.shape
# Out:
# (1002, 21)

# %%
pd.set_option('display.max_rows', 1002)

# %%
pd.set_option('display.max_columns', 30)

# %%
df
# Out:
#      checking_status  duration                  credit_history  \
# 0                 <0         6  critical/other existing credit
# 1           0<=X<200        48                   existing paid
# 2        no checking        12  critical/other existing credit
# 3                 <0        42                   existing paid
# 4                 <0        24              delayed previously
# ...              ...       ...                             ...
# 997      no checking        12                   existing paid
# 998               <0        45                   existing paid
# 999         0<=X<200        45  critical/other existing credit
# 1000              <0        48                   existing paid
# 1005     no checking        24  critical/other existing credit
#
#                   purpose credit_amount    savings_status  employment  \
# 0                radio/tv        1169.0  no known savings         >=7
# ...

# %%
df = df.copy()

# %%
df[['sex', 'marital_status']]= df['personal_status'].str.split(' ', expand = True) #split columns and assign values

# %%
df.drop(columns = 'personal_status', inplace = True)

# %%
df
# Out:
#      checking_status  duration                  credit_history  \
# 0                 <0         6  critical/other existing credit
# 1           0<=X<200        48                   existing paid
# 2        no checking        12  critical/other existing credit
# 3                 <0        42                   existing paid
# 4                 <0        24              delayed previously
# ...              ...       ...                             ...
# 997      no checking        12                   existing paid
# 998               <0        45                   existing paid
# 999         0<=X<200        45  critical/other existing credit
# 1000              <0        48                   existing paid
# 1005     no checking        24  critical/other existing credit
#
#                   purpose credit_amount    savings_status  employment  \
# 0                radio/tv        1169.0  no known savings         >=7
# ...

# %%
df = df.drop(columns = 'own_telephone') #drop useless columns

# %%
df
# Out:
#      checking_status  duration                  credit_history  \
# 0                 <0         6  critical/other existing credit
# 1           0<=X<200        48                   existing paid
# 2        no checking        12  critical/other existing credit
# 3                 <0        42                   existing paid
# 4                 <0        24              delayed previously
# ...              ...       ...                             ...
# 997      no checking        12                   existing paid
# 998               <0        45                   existing paid
# 999         0<=X<200        45  critical/other existing credit
# 1000              <0        48                   existing paid
# 1005     no checking        24  critical/other existing credit
#
#                   purpose credit_amount    savings_status  employment  \
# 0                radio/tv        1169.0  no known savings         >=7
# ...

# %%
df['marital_status']= df['marital_status'].str.replace('mar/wid', 'widowed') #standardize the columns

# %%
df['marital_status']= df['marital_status'].str.replace('div/dep/mar', 'divorced')

# %%
df['marital_status'] = df['marital_status']= df['marital_status'].str.replace('div/sep', 'divorced')

# %%
df['marital_status']
# Out:
# 0         single
# 1       divorced
# 2         single
# 3         single
# 4         single
#           ...
# 997       single
# 998       single
# 999       single
# 1000    divorced
# 1005      single
# Name: marital_status, Length: 1002, dtype: object

# %%
df
# Out:
#      checking_status  duration                  credit_history  \
# 0                 <0         6  critical/other existing credit
# 1           0<=X<200        48                   existing paid
# 2        no checking        12  critical/other existing credit
# 3                 <0        42                   existing paid
# 4                 <0        24              delayed previously
# ...              ...       ...                             ...
# 997      no checking        12                   existing paid
# 998               <0        45                   existing paid
# 999         0<=X<200        45  critical/other existing credit
# 1000              <0        48                   existing paid
# 1005     no checking        24  critical/other existing credit
#
#                   purpose credit_amount    savings_status  employment  \
# 0                radio/tv        1169.0  no known savings         >=7
# ...

# %%
df['job'] = df['job'].str.replace('high qualif/self emp/mgmt','self_employed')

# %%
df
# Out:
#      checking_status  duration                  credit_history  \
# 0                 <0         6  critical/other existing credit
# 1           0<=X<200        48                   existing paid
# 2        no checking        12  critical/other existing credit
# 3                 <0        42                   existing paid
# 4                 <0        24              delayed previously
# ...              ...       ...                             ...
# 997      no checking        12                   existing paid
# 998               <0        45                   existing paid
# 999         0<=X<200        45  critical/other existing credit
# 1000              <0        48                   existing paid
# 1005     no checking        24  critical/other existing credit
#
#                   purpose credit_amount    savings_status  employment  \
# 0                radio/tv        1169.0  no known savings         >=7
# ...
